# %%
import gge
from gge import sensors

# %%
from gge import reanalysis

# %%
area = (12.1, 55.60, 12.14, 55.62)  # Define the area
time_range = ('2024-04-01', '2024-04-03') 


area = "/Users/kaaso/Documents/phd/coding/gge/Notebooks/arkansas_Nuclear_one.geojson"

# %%
# Create a Landsat instance and use it
reanalysis1 = reanalysis.ERA5LandHourly()
reanalysis1.variable = "total_precipitation_hourly"
reanalysis1.area = area
reanalysis1.time_range = time_range
reanalysis1.download_data()
# Out:
# 2025-11-12 15:38:09,436 - root - INFO - Initializing Earth Engine... (SatelliteData.py:26)
# 2025-11-12 15:38:12,185 - root - INFO - Earth Engine initialized. (SatelliteData.py:36)

# %%
reanalysis
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 len(reanalysis1)
#
# TypeError: object of type 'ERA5LandHourly' has no len()

# %%
reanalysis1.plot_time_series()

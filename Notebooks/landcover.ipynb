# %%
import sys

# %%
sys.path.append("../src")
sys.path.append("..")

# %%
from gge import landcover

# %%
area = (12.1, 55.60, 12.14, 55.62)  # Define the area

# %%
# Create a Landsat instance and use it
corine_land_cover = landcover.CORINELandCover()
corine_land_cover.area = area
# Out:
# 2024-06-27 11:43:45,546 - root - INFO - Initializing Earth Engine... (SatelliteData.py:23)
# 2024-06-27 11:43:47,059 - root - INFO - Earth Engine initialized. (SatelliteData.py:29)

# %%
# Download the data
corine_land_cover.download_data()
# Out:
# 2024-06-27 11:43:47,318 - root - INFO - download_data executed in 0.253 seconds. (exception_handler.py:10)

# %%
import numpy as np

# %%
# Display the land cover data
corine_land_cover.display_land_cover()

# %%
land_cover = landcover.ESAWorldCover()
land_cover.area = area

# %%
land_cover.download_data()
# Out:
# 2024-06-27 11:43:47,837 - root - INFO - download_data executed in 0.367 seconds. (exception_handler.py:10)

# %%
land_cover.display_world_cover()

# %%
land_cover2 = landcover.Sentinel2WorldCover()
land_cover2.area = area
land_cover2.download_data()
land_cover2.display_world_cover()
# Out:
# 2024-06-27 11:43:48,267 - root - INFO - download_data executed in 0.339 seconds. (exception_handler.py:10)

# %%
land_cover3 = landcover.CGLSLandCover100()
land_cover3.area = area
land_cover3.download_data()
land_cover3.display_world_cover()
# Out:
# 2024-06-27 11:43:48,679 - root - INFO - download_data executed in 0.317 seconds. (exception_handler.py:10)

# %%
land_cover3.geometry
# Out:
# {'type': 'Polygon',
#  'coordinates': [[[12.1, 55.6],
#    [12.14, 55.6],
#    [12.14, 55.62],
#    [12.1, 55.62],
#    [12.1, 55.6]]]}

# %%
corine_land_cover.geometry
# Out:
# {'type': 'Polygon',
#  'coordinates': [[[12.1, 55.6],
#    [12.14, 55.6],
#    [12.14, 55.62],
#    [12.1, 55.62],
#    [12.1, 55.6]]]}

# %%
land_cover.geometry
# Out:
# {'type': 'Polygon',
#  'coordinates': [[[12.1, 55.6],
#    [12.14, 55.6],
#    [12.14, 55.62],
#    [12.1, 55.62],
#    [12.1, 55.6]]]}

# %%
land_cover2.geometry
# Out:
# {'type': 'Polygon',
#  'coordinates': [[[12.1, 55.6],
#    [12.14, 55.6],
#    [12.14, 55.62],
#    [12.1, 55.62],
#    [12.1, 55.6]]]}

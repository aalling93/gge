# %%
import gge
from gge import sensors

# %%
area = (12.1, 55.60, 12.2, 55.7)  # Define the area

area = "/Users/kaaso/Documents/phd/coding/gge/data/location/bunaeset/POLYGON.shp"

# %%
import geopandas as gpd

# %%
# readh shp as geopands
gdf = gpd.read_file(area)

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
# Create a Landsat instance and use it
landsat = sensors.Landsat(area, ('2024-04-01', '2024-07-01') )
landsat.download_data()
# Out:
# 2024-07-01 09:57:56,487 - root - INFO - Initializing Earth Engine... (SatelliteData.py:23)
# 2024-07-01 09:58:00,751 - root - INFO - Earth Engine initialized. (SatelliteData.py:29)
# 2024-07-01 09:58:00,755 - root - INFO - CRS is EPSG:4326 (with The GeoSeries already has a CRS which is not equal to the passed CRS. Specify 'allow_override=True' to allow replacing the existing CRS without doing any transformation. If you actually want to transform the geometries, use 'GeoSeries.to_crs' instead.) (SatelliteData.py:70)
# No images found in collection LANDSAT/LT04/C02/T1_L2 for the given filters.
# No images found in collection LANDSAT/LT05/C02/T1_L2 for the given filters.
# No images found in collection LANDSAT/LE07/C02/T1_L2 for the given filters.
# 2024-07-01 09:59:13,039 - root - INFO - download_data executed in 72.282 seconds. (exception_handler.py:10)
# No images found in collection LANDSAT/LC09/C02/T2_L2 for the given filters.

# %%
len(landsat.images_data)
# Out:
# 7

# %%
len(landsat)
# Out:
# 7

# %% [markdown]
# or

# %%
landsat.dn_to_reflectance()

# %% [markdown]
# We can see the RGB images if we want to

# %%
# %matplotlib inline

# %%
landsat.display_rgb(6, gamma = 0.4, gain = 1.3)

# %% [markdown]
# Or, we get get the items

# %%
landsat.item_type = "RGB"

# %%
img, meta = landsat[0]

# %%
import matplotlib.pyplot as plt

# %%
img, meta = landsat[0]
img5, meta5 = landsat[5]

# %%
np.quantile(img5,0.8)
# Out:
# np.float64(0.0)

# %%
np.quantile(img,0.2)
# Out:
# np.float64(21.0)

# %%
plt.subplot(1, 7, 1)
img, meta = landsat[0]
plt.imshow(img, cmap='gray')
h,w,c = img.shape
plt.vlines(w/2, 0, h, color='r', alpha=0.5)
plt.hlines(h/2, 0, w, color='r', alpha=0.5)
plt.subplot(1, 7, 2)
img, meta = landsat[1]
plt.imshow(img, cmap='gray')
h,w,c = img.shape
plt.vlines(w/2, 0, h, color='r', alpha=0.5)
plt.hlines(h/2, 0, w, color='r', alpha=0.5)
plt.subplot(1, 7, 3)
img, meta = landsat[2]
plt.imshow(img, cmap='gray')
h,w,c = img.shape
plt.vlines(w/2, 0, h, color='r', alpha=0.5)
plt.hlines(h/2, 0, w, color='r', alpha=0.5)
plt.subplot(1, 7, 4)
img, meta = landsat[3]
plt.imshow(img, cmap='gray')
h,w,c = img.shape
plt.vlines(w/2, 0, h, color='r', alpha=0.5)
plt.hlines(h/2, 0, w, color='r', alpha=0.5)
plt.subplot(1, 7, 5)
img, meta = landsat[4]
plt.imshow(img, cmap='gray')
h,w,c = img.shape
plt.vlines(w/2, 0, h, color='r', alpha=0.5)
plt.hlines(h/2, 0, w, color='r', alpha=0.5)

plt.subplot(1, 7, 6)
img, meta = landsat[5]
plt.imshow(img, cmap='gray')
h,w,c = img.shape
plt.vlines(w/2, 0, h, color='r', alpha=0.5)
plt.hlines(h/2, 0, w, color='r', alpha=0.5)

plt.subplot(1, 7, 7)
img, meta = landsat[6]
plt.imshow(img, cmap='gray')
h,w,c = img.shape
plt.vlines(w/2, 0, h, color='r', alpha=0.5)
plt.hlines(h/2, 0, w, color='r', alpha=0.5)
